# %%
import pandas as pd

df = pd.read_csv("../data/housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# B. Describe each attribute, explaining Its real-world meaning and whether it is numerical or categorical

# %%
pip install tabulate
# Out:
# Collecting tabulate
#   Downloading tabulate-0.10.0-py3-none-any.whl.metadata (40 kB)
# Downloading tabulate-0.10.0-py3-none-any.whl (39 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.10.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from tabulate import tabulate

data = {
    "Attribute": [
        "Longitude", "Latitude", "Housing Median Age", "Total Rooms",
        "Total Bedrooms", "Population", "Households",
        "Median Income", "Median House Value", "Ocean Proximity"
    ],
    "Description": [
        "A measure of how far west a house block group is located; higher values are farther west",
        "A measure of how far north a house block group is located; higher values are farther north",
        "Median age in years of houses within a block group; lower values indicate newer buildings",
        "Total number of rooms across all houses within a block group",
        "Total number of bedrooms across all houses within a block group",
        "Total number of people residing within the block group",
        "Total number of households within a block group",
        "Median household income within the block group, measured in tens of thousands of USD",
        "Median monetary value in USD of all houses within the block group",
        "Location of the house with respect to the ocean or sea"
    ],
    "Real-World Meaning": [
        "Identifies the east–west geographic position of district block groups for spatial price analysis",
        "Identifies the north–south geographic position used to map housing patterns",
        "Describes whether neighborhoods are newly developed or long established",
        "Indicates housing size and density; meaningful when normalized by households",
        "Represents sleeping capacity of the housing stock",
        "Reflects settlement density and occupancy levels",
        "Used as a denominator for per-household feature engineering",
        "Strong indicator of socioeconomic status and housing demand",
        "Represents neighborhood-level housing affordability and market value",
        "Captures coastal proximity, a major driver of property prices in California"
    ],
    "Data Type": [
        "Numerical", "Numerical", "Numerical", "Numerical", "Numerical",
        "Numerical", "Numerical", "Numerical", "Numerical", "Categorical"
    ]
}

df = pd.DataFrame(data)

# Print justified table with borders
print(tabulate(
    df,
    headers="keys",
    tablefmt="grid",
    showindex=False,
    colalign=("left", "left", "left", "center")
))
# Out:
# +--------------------+--------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------+-------------+
# | Attribute          | Description                                                                                | Real-World Meaning                                                                               |  Data Type  |
# +====================+============================================================================================+==================================================================================================+=============+
# | Longitude          | A measure of how far west a house block group is located; higher values are farther west   | Identifies the east–west geographic position of district block groups for spatial price analysis |  Numerical  |
# +--------------------+--------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------+-------------+
# | Latitude           | A measure of how far north a house block group is located; higher values are farther north | Identifies the north–south geographic position used to map housing patterns                      |  Numerical  |
# +--------------------+--------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------+-------------+
# | Housing Median Age | Median age in years of houses within a block group; lower values indicate newer buildings  | Describes whether neighborhoods are newly developed or long established                          |  Numerical  |
# +--------------------+--------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------+-------------+
# | Total Rooms        | Total number of rooms across all houses within a block group                               | Indicates housing size and density; meaningful when normalized by households                     |  Numerical  |
# +--------------------+--------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------+-------------+
# | Total Bedrooms     | Total number of bedrooms across all houses within a block group                            | Represents sleeping capacity of the housing stock                                                |  Numerical  |
# +--------------------+--------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------+-------------+
# | Population         | Total number of people residing within the block group                                     | Reflects settlement density and occupancy levels                                                 |  Numerical  |
# +--------------------+--------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------+-------------+
# | Households         | Total number of households within a block group                                            | Used as a denominator for per-household feature engineering                                      |  Numerical  |
# +--------------------+--------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------+-------------+
# | Median Income      | Median household income within the block group, measured in tens of thousands of USD       | Strong indicator of socioeconomic status and housing demand                                      |  Numerical  |
# +--------------------+--------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------+-------------+
# | Median House Value | Median monetary value in USD of all houses within the block group                          | Represents neighborhood-level housing affordability and market value                             |  Numerical  |
# +--------------------+--------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------+-------------+
# | Ocean Proximity    | Location of the house with respect to the ocean or sea                                     | Captures coastal proximity, a major driver of property prices in California                      | Categorical |
# +--------------------+--------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------+-------------+

# %% [markdown]
# same but different display

# %%
import pandas as pd

# Create dataset attribute documentation
data = {
    "Attribute": [
        "Longitude",
        "Latitude",
        "Housing Median Age",
        "Total Rooms",
        "Total Bedrooms",
        "Population",
        "Households",
        "Median Income",
        "Median House Value",
        "Ocean Proximity"
    ],
    
    "Description": [
        "A measure of how far west a house block group is located; higher values are farther west",
        "A measure of how far north a house block group is located; higher values are farther north",
        "Median age in years of houses within a block group; lower values indicate newer buildings",
        "Total number of rooms across all houses within a block group",
        "Total number of bedrooms across all houses within a block group",
        "Total number of people residing within the block group",
        "Total number of households (groups of people residing in a single home unit) within a block",
        "Median household income within the block group, measured in tens of thousands of USD",
        "Median monetary value in USD of all houses within the block group",
        "Location of the house with respect to the ocean or sea"
    ],
    
    "Real-World Meaning": [
        "Identifies the east-west geographic position of each district block group in California. Used alongside latitude for spatial price analysis",
        "Identifies the north-south geographic position of each district block group. Combined with longitude to map housing patterns across California",
        "Captures the age profile of the housing stock. Older neighborhoods reflect established communities, while newer ones indicate recent development",
        "Reflects the overall size and density of housing within a block. Often normalized by households for meaningful interpretation",
        "Indicates the sleeping capacity of the housing stock within a block",
        "Captures the human settlement density of the block and helps estimate occupancy levels",
        "Key denominator variable for deriving per-household metrics during feature engineering",
        "Captures the socioeconomic character of the neighborhood and is a strong predictor of house prices",
        "Represents housing affordability and market valuation at neighborhood level and is often the target variable",
        "Captures coastal proximity, a well-known driver of property values in California"
    ],
    
    "Data Type": [
        "Numerical",
        "Numerical",
        "Numerical",
        "Numerical",
        "Numerical",
        "Numerical",
        "Numerical",
        "Numerical",
        "Numerical",
        "Categorical"
    ]
}

# Create DataFrame
attributes_df = pd.DataFrame(data)

# Display the table
attributes_df
# Out:
#             Attribute                                        Description  \
# 0           Longitude  A measure of how far west a house block group ...
# 1            Latitude  A measure of how far north a house block group...
# 2  Housing Median Age  Median age in years of houses within a block g...
# 3         Total Rooms  Total number of rooms across all houses within...
# 4      Total Bedrooms  Total number of bedrooms across all houses wit...
# 5          Population  Total number of people residing within the blo...
# 6          Households  Total number of households (groups of people r...
# 7       Median Income  Median household income within the block group...
# 8  Median House Value  Median monetary value in USD of all houses wit...
# 9     Ocean Proximity  Location of the house with respect to the ocea...
#
#                                   Real-World Meaning    Data Type
# 0  Identifies the east-west geographic position o...    Numerical
# 1  Identifies the north-south geographic position...    Numerical
# 2  Captures the age profile of the housing stock....    Numerical
# 3  Reflects the overall size and density of housi...    Numerical
# 4  Indicates the sleeping capacity of the housing...    Numerical
# 5  Captures the human settlement density of the b...    Numerical
# 6  Key denominator variable for deriving per-hous...    Numerical
# 7  Captures the socioeconomic character of the ne...    Numerical
# 8  Represents housing affordability and market va...    Numerical
# 9  Captures coastal proximity, a well-known drive...  Categorical
